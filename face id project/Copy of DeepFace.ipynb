# %%
# !pip install deepface &> /dev/Name
print("Deepface Installed....")
# Out:
# Deepface Installed....

# %%
from deepface import DeepFace
import cv2 #computer vision libraray to read images
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
read1=cv2.imread('/content/smile.jpg')
result=DeepFace.analyze(read1)
result
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.76it/s]
# {'emotion': {'angry': 2.5502538392174756e-05,
#   'disgust': 1.4720059893225113e-08,
#   'fear': 0.003005988401127979,
#   'happy': 99.97674822807312,
#   'sad': 0.005287369640427642,
#   'surprise': 0.004803945193998516,
#   'neutral': 0.010130844748346135},
#  'dominant_emotion': 'happy',
#  'region': {'x': 217, 'y': 65, 'w': 120, 'h': 120},
#  'age': 28,
#  'gender': 'Woman',
#  'race': {'asian': 53.39159965515137,
#   'indian': 9.186331182718277,
#   'black': 12.196611613035202,
#   'white': 2.3233069106936455,
#   'middle eastern': 1.092610228806734,
#   'latino hispanic': 21.809542179107666},
#  'dominant_race': 'asian'}

# %%
print("dominant emotion in image is:",result['dominant_emotion'])
# Out:
# dominant emotion in image is: happy

# %%
result3=DeepFace.verify('/content/ANI-20221105054416.jpg','/content/319946.webp')
# Out:
# ...
# 1/1 [==============================] - 1s 589ms/step

# %%
result3
# Out:
# {'verified': True,
#  'distance': 0.17378257645461948,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
print('verified=',result3['verified'])
# Out:
# verified= True

# %%
#take video of choice and get 50 pics and check dominant emotion

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
vidcap = cv2.VideoCapture('/content/ENG v PAK WC Final Match(1).mp4')

# %%
#code to get 1st 50 frames of the video
success,image = vidcap.read()
count = 1;
while success:
  if count<51:
    success,image = vidcap.read()
    cv2.imwrite("frame%d.jpg" % count, image)       # save frame as JPEG file
    count += 1
  else:
    break

# %%
loop=1;
happy=0;
angry=0;
disgust=0;
fear=0;
sad=0;
surprise=0;
neutral=0;
while loop<51:
  print(loop)
  read_frame=cv2.imread("frame%d.jpg" % loop)
  result_loop=DeepFace.analyze(read_frame)
  if(result_loop['dominant_emotion']=='happy'):
    happy += 1
  elif(result_loop['dominant_emotion']=='angry'):
    angry+=1
  elif(result_loop['dominant_emotion']=='disgust'):
    disgust+=1
  elif(result_loop['dominant_emotion']=='fear'):
    fear+=1
  elif(result_loop['dominant_emotion']=='sad'):
    sad+=1
  elif(result_loop['dominant_emotion']=='surprise'):
    surprise+=1
  else:
    neutral+=1
  loop+=1
Max=max('happy','angry','disgust','fear','sad','surprise')
print("\nthe dominat emotion in 1st 50 frames is:",Max)
# Out:
# 1
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
# 2
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.38it/s]
# 3
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# 4
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# 5
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.37it/s]
# 6
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.09it/s]
# 7
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.36it/s]
# 8
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.35it/s]
# 9
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.37it/s]
# 10
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# 11
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s]
# 12
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# 13
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# 14
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s]
# 15
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.37it/s]
# ...

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
a='/content/'+filename;
read01=cv2.imread(a)
result01=DeepFace.analyze(read01)
result01
# Out:
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# facial_expression_model_weights.h5 will be downloaded...
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 213MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# age_model_weights.h5 will be downloaded...
# 100%|██████████| 539M/539M [00:01<00:00, 395MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# gender_model_weights.h5 will be downloaded...
# 100%|██████████| 537M/537M [00:01<00:00, 328MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
print("the dominant emotion is:", result01['dominant_emotion'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7dbcde90006c> in <cell line: 1>()
# ----> 1 print("the dominant emotion is:", result01['dominant_emotion'])
#
# TypeError: list indices must be integers or slices, not str

# %%
from IPython.display import Image
try:
  filename1 = take_photo('pic.jpg')
  print('Saved to {}'.format(filename1))

  # Show the image which was just taken.
  display(Image(filename1))
except Exception as err1:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err1))
# Out:
# Saved to pic.jpg

# %%
b='/content/'+filename1;
result_verify=DeepFace.verify(a,b)
print('verified=',result_verify['verified'])
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:06<00:00, 85.9MB/s]
# verified= True
